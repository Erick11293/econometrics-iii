# %%
library("R.matlab")
# Out:
# R.matlab v3.7.0 (2022-08-25 21:52:34 UTC) successfully loaded. See ?R.matlab for help.
#
#
# Attaching package: ‘R.matlab’
#
#
# The following objects are masked from ‘package:base’:
#
#     getOption, isOpen

# %%
library("RDHonest")

# %%
data <- readMat('../data/jacob_lefgren.mat')

# %%
head(data)

# %%
RDHonest(
rmath1 | summer ~ ,
data,
subset,
weights,
cutoff = 0,
M,
kern = "triangular",
na.action,
opt.criterion = "MSE",
h,
se.method = "nn",
RDHonest 7
alpha = 0.05,
beta = 0.8,
J = 3,
sclass = "H",
T0 = 0,
point.i
